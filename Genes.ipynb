# %%
#pip install urllib3

# %%
#pip install gseapy

# %%
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with 4 connections
#df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C']})
HPNCC = pd.DataFrame({'from':['HPNCC','HPNCC'], 'to':['Hereditary nonpolyposis colorectal cancer',' Familial nonpolyposis colorectal cancer']})

 
# Build your graph
G=nx.from_pandas_edgelist(HPNCC, 'from', 'to')
 
# Plot it
nx.draw(G, with_labels=True)
plt.show()

# %%
Fanconi_anemia = pd.DataFrame({'from':['Fanconi anemia','Fanconi anemia','Fanconi anemia','Fanconi anemia','Fanconi anemia','Fanconi anemia'], 'to':['Congenital aplastic anaemia','DNA instability syndromes affecting the skin','Inherited cancer-predisposing syndromes', 'Fanconi-ichthyosis-dysmorphism syndrome','Fanconi hypoplastic anaemia','Fanconi familial refractory anaemia']})
# Build your graph
G=nx.from_pandas_edgelist(Fanconi_anemia, 'from', 'to')
 
# Plot it
nx.draw(G, with_labels=True)
plt.show()

# %%
Malignant_Melanoma = pd.DataFrame({'from':['Carney Stratakis syndrome','Multiple polyglandular tumours','Neoplasms of uncertain behaviour withpluriglandular involvement'],'to':['Multiple polyglandular tumours','Neoplasms of uncertain behaviour withpluriglandular involvement','Neoplasms of uncertain behaviour of endocrineglands']})
# Build your graph
G=nx.from_pandas_edgelist(Malignant_Melanoma, 'from', 'to')
 
# Plot it
nx.draw(G, with_labels=True)
plt.show()

# %%
Carney_Stratakis_syndrome = pd.DataFrame({'from':['Carney Stratakis syndrome','Multiple polyglandular tumours','Multiple polyglandular tumours','Neoplasms of uncertain behaviour withpluriglandular involvement'],'to':['Multiple polyglandular tumours','Neoplasms of uncertain behaviour withpluriglandular involvement','Polyglandular dysfunction','Neoplasms of uncertain behaviour of endocrineglands']})
# Build your graph
G=nx.from_pandas_edgelist(Carney_Stratakis_syndrome, 'from', 'to')
 
# Plot it
nx.draw(G, with_labels=True)
plt.show()

# %%
#pip install requests

# %%
#pip install html5lib

# %%
#pip install bs4

# %%
import pandas as pd

Linear = pd.read_excel('LinearizationMiniOutput-MMS-en.xlsx')
Linear.head()
# Out:
#                             Foundation URI  \
# 0  http://id.who.int/icd/entity/1435254666
# 1   http://id.who.int/icd/entity/588616678
# 2   http://id.who.int/icd/entity/135352227
# 3   http://id.who.int/icd/entity/257068234
# 4   http://id.who.int/icd/entity/416025325
#
#                          Linearization (release) URI  Code      BlockId  \
# 0  http://id.who.int/icd/release/11/beta/mms/1435...   NaN          NaN
# 1  http://id.who.int/icd/release/11/beta/mms/5886...   NaN  BlockL1-1A0
# 2  http://id.who.int/icd/release/11/beta/mms/1353...   NaN  BlockL2-1A0
# 3  http://id.who.int/icd/release/11/beta/mms/2570...  1A00          NaN
# 4  http://id.who.int/icd/release/11/beta/mms/4160...  1A01          NaN
#
#                                                Title ClassKind  DepthInKind  \
# 0           Certain infectious or parasitic diseases   chapter            1
# 1  - Gastroenteritis or colitis of infectious origin     block            1
# ...

# %%
notes_sample1 = Linear.loc[(Linear['Title']== '- - - - Non-secreting pituitary adenoma')|(Linear['Title']== '- - - - Acute myeloid leukaemia, NOS')|(Linear['Title']== '- - - - - Malignant phaeochromocytoma of adrenal gland')|
                          (Linear['Title']== '- - - - DNA repair defects other than combined T-cell or B-cell immunodeficiencies')|(Linear['Title']== '- - - - Other specified Cushing syndrome')|
                          (Linear['Title']== '- - - - Chordoma, NOS')|(Linear['Title']== '- - - Other specified phakomatoses or hamartoneoplastic syndromes')|
                          (Linear['Title']== '- - - Nephrotic syndrome')|(Linear['Title']== '- - - - Aggressive fibromatosis')|
                          (Linear['Title']== '- - - Congenital aplastic anaemia')|(Linear['Title']== '- - - - Benign osteogenic tumour of unspecified site')|
                          (Linear['Title']== '- - - - - - - Other specified malignant neoplasms of colon')|(Linear['Title']== '- - - - Noonan syndrome')|
                          (Linear['Title']== '- - - Fibrous dysplasia of bone')]
notes_sample1
# Out:
#                                 Foundation URI  \
# 1534                                       NaN
# 1929   http://id.who.int/icd/entity/2110009016
# 2119                                       NaN
# 2247   http://id.who.int/icd/entity/1197752358
# 2428    http://id.who.int/icd/entity/350719523
# 2629   http://id.who.int/icd/entity/1362501774
# 2997                                       NaN
# 9361   http://id.who.int/icd/entity/1704766818
# 9798   http://id.who.int/icd/entity/1184209951
# 12292                                      NaN
# 12309  http://id.who.int/icd/entity/1044395354
# 23839  http://id.who.int/icd/entity/1314962913
# 24119  http://id.who.int/icd/entity/1455398050
# 24729   http://id.who.int/icd/entity/871951185
#
#                              Linearization (release) URI     Code BlockId  \
# 1534   http://id.who.int/icd/release/11/beta/mms/1265...   2B90.Y     NaN
# 1929   http://id.who.int/icd/release/11/beta/mms/2110...   2D11.1     NaN
# ...

# %%
Description = ['Malignant phaeochromocytoma of adrenal gland', 'Non-secreting pituitary adenoma', 
               'Bloom syndrome', 'Carney complex', 'Chordoma', 'Cowden syndrome', 'Denys-Drash syndrome', 'Aggressive fibromatosis',
               'Dyskeratosis congenita', 'Noonan syndrome or related disorders','Enchondromatosis', 'Familial adenomatous polyposis', 
               'McCune-Albright syndrome', 'Acute myeloid leukaemia, NOS']
Genes = ['(AIP)', '(CEBPA)', '(MAX, TMEM127, VHL)', '(BLM)', '(CNC2#, PRKAR1A)', '(T/TFT)', '(ATK1, KILLIN, PIK3CA, PTEN, SDHB, SDHD)', '(WT1)', '(APC)', '(DKC1, TERC, TERT, TINF2)', '(IDH1, IDH2, PTHR1)', '(APC)', '(CBL, KRAS, NRAS, PTPN11, RAF1, SOS1)', '(GNAS1)']
notes_sample1['DESCRIPTION'] = Description
notes_sample1['GENES'] = Genes
notes_sample1
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                 Foundation URI  \
# 1534                                       NaN
# 1929   http://id.who.int/icd/entity/2110009016
# 2119                                       NaN
# 2247   http://id.who.int/icd/entity/1197752358
# ...

# %%
disease =
